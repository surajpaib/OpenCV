# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
## All code and functions are defined in lemon.py
from lemon import LemonRecognizer

# %%
K = LemonRecognizer('/home/suraj/Repositories/LemonRecognition/lemon.jpeg')
print K
im = K.get_image()
plt.imshow(im)
plt.title('HSV sample image of lemons')
# Out:
# <lemon.LemonRecognizer object at 0x7f1cdb897e50>

# %%
## Using contours to find approximate circle radius
(x, y), radius = K.get_min_enclosed_circle()
cv2.circle(im, (int(x), int(y)), int(radius),(255, 255, 255), 4, 2)
plt.imshow(im)
plt.title('Minimum Enclosing Circle')

# %%
circles = K.hough_circle_transform()
print circles
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-14-c801ab66b822> in <module>()
# ----> 1 circles = K.hough_circle_transform()
#       2 print circles
#
# /home/suraj/Repositories/LemonRecognition/lemon.pyc in hough_circle_transform(self)
#      37         return (x, y), self.radius
#      38
# ---> 39     def hough_circle_transform(self):
#      40         """
#      41         Use hough circle method to find circles in the image to fit a given criteria ( In this case,
#
# NameError: global name 'bw' is not defined
